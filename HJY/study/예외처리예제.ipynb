# %%
#넘피 호출
import numpy as np

#Numpy 배열로 변환
#arr = np.array([1,2,3])

#arange(시작값, 종료값, 건너뛰기)
#arr = np.arange(0,10,2)

#0과 1사이 균일 분포를 따르는 난수 생성
#arr = np.random.rand(3,3)       #np.ramdom:난수생성/ rand:0~1난수 3행3열

#배열 shape변경
#arr = arr.reshape(1,9)          #1행 9열

arr
# Out:
# np.int64(6)

# %%
#넘피 호출
import numpy as np
#합계
#np.sum([1,2,3])

#평균
#np.mean([1,2,3])

#표준편차
np.std([1,2,3])
# Out:
# np.float64(0.816496580927726)

# %%
#Pandas

import os
#print(os.getcwd())  # 현재 작업 디렉토리 확인
#print(os.listdir())  # 현재 디렉토리의 파일 목록 확인
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('dataset/diabetes.csv')

# 당뇨병 데이터 불러오기 (데이터 파일 경로 변경 필요)
df.head()

df.info()

df.describe()

# 각 변수의 분포 확인
#df.hist(figsize=(10, 8))
#plt.show()

# 변수 간 상관관계 시각화
#sns.heatmap(df.corr(), annot=True)
#plt.show()


# 결측치 확인
#df.insnull().sum()

# 결측치 평균값으로 채우기
df.fillna(df.mean(), inplace=True)  # inplace = True 는 변경된설정으로 덮어쓴다는 의미
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# ...

# %%
#Matplotlib함수

import matplotlib.pyplot as plt
import numpy as np

# 데이터 생성
x = np.linspace(0,10,100)
y = np.sin(x)

# 선 그래프
#plt.plot(x,y)       
#plt.xlabel('x')
#plt.ylabel('sin(x)')
#plt.title('Sine Wave')
#plt.show()

#산점도
#plt.scatter(x,y)
#plt.show()

#막대그래프
#data = [3,8,1,10]
#plt.bar(['A', 'B', 'C', 'D'], data)
#plt.show()

# 히스토그램
np.random.seed(19680801)
data = np.random.randn(1000)
plt.hist(data, bins=30)     #bin은x축
plt.show()

# %%
#Seaborn 함수
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#팁 데이터 불러오기
tips = sns.load_dataset("tips")

#팁 금액 분포 시각화
sns.displot(tips['tip'], kde=True)
plt.show()
